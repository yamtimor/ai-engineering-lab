# %% [markdown]
# # Basic Stock Agent

# %%
import yf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import yf
#
# File ~/Documents/ai-engineering-lab/.venv/lib/python3.11/site-packages/yf/__init__.py:6
#       4 import pprint
#       5 import numpy as np
# ----> 6 import pandas as pd
#       7 import json
#       8 from ut.pdict.get import iter_key_path_items
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Basic Agent
